# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')

# For embeddings
from sentence_transformers import SentenceTransformer

# For vector database
import chromadb

# For LLM
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM

# For progress tracking
from tqdm import tqdm

print(" All libraries imported successfully!")
print(f"Current directory: {os.getcwd()}")
# Out:
#  All libraries imported successfully!
# Current directory: C:\Users\PC\Desktop\rag-complaint-chatbot-10academy\notebooks

# %%
print("=" * 50)
print("STEP 1: LOADING PRE-BUILT VECTOR STORE")
print("=" * 50)

# Check if the parquet file exists
parquet_path = '../data/raw/complaint_embeddings.parquet'
if not os.path.exists(parquet_path):
    print(" complaint_embeddings.parquet not found!")
    print("Downloading from Google Drive...")
    import gdown
    file_id = '1T-Rfs13riuawtf6MW0nhVuQmBQLKV9Fh'
    url = f'https://drive.google.com/uc?id={file_id}'
    os.makedirs('../data/raw', exist_ok=True)
    gdown.download(url, parquet_path, quiet=False)
    print(" Download complete!")

# Load the parquet file
df_embeddings = pd.read_parquet(parquet_path)

print(f"\n Loaded pre-built vector store!")
print(f"   Total chunks: {len(df_embeddings):,}")
print(f"   Columns: {df_embeddings.columns.tolist()}")
print(f"   Memory usage: {df_embeddings.memory_usage(deep=True).sum() / 1024**3:.2f} GB")

# Check embedding dimension
if 'embedding' in df_embeddings.columns:
    embedding_dim = len(df_embeddings['embedding'].iloc[0])
    print(f"   Embedding dimension: {embedding_dim} (all-MiniLM-L6-v2 ✓)")
# Out:
# ...
# STEP 1: LOADING PRE-BUILT VECTOR STORE
# ...
#  complaint_embeddings.parquet not found!
# ...
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# File ~\Desktop\rag-complaint-chatbot-10academy\venv\Lib\site-packages\gdown\download.py:313, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress, skip_download)
#     312 try:
# --> 313     url = get_url_from_gdrive_confirmation(res.text)
#     314 except FileURLRetrievalError as e:
#
# File ~\Desktop\rag-complaint-chatbot-10academy\venv\Lib\site-packages\gdown\download.py:70, in get_url_from_gdrive_confirmation(contents)
#      69 if not url:
# ---> 70     raise FileURLRetrievalError(
#      71         "Cannot retrieve the public link of the file. "
#      72         "You may need to change the permission to "
# ...
